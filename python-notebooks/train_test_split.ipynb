# %%
import pandas as pd
import numpy as np

# %%
bkk_all = pd.read_csv('../data/bkk_all.csv')[['DateTime', 'FolderPath', 'FileName']]

# %%
bkk_all
# Out:
#                   DateTime                                   FolderPath  \
# 0      2020-06-18 06:30:00   /data/bkk_radar_images/bkk_radar_images_1/
# 1      2020-06-18 06:35:00   /data/bkk_radar_images/bkk_radar_images_1/
# 2      2020-06-18 06:45:00   /data/bkk_radar_images/bkk_radar_images_1/
# 3      2020-06-18 06:50:00   /data/bkk_radar_images/bkk_radar_images_1/
# 4      2020-06-18 06:55:00   /data/bkk_radar_images/bkk_radar_images_1/
# ...                    ...                                          ...
# 85384  2021-06-28 20:05:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85385  2021-06-28 20:35:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85386  2021-06-28 20:45:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85387  2021-06-28 21:15:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85388  2021-06-28 21:20:00  /data/bkk_radar_images/bkk_radar_images_13/
#
#              FileName
# 0      1592461954.png
# 1      1592462136.png
# 2      1592462768.png
# ...

# %% [markdown]
# ## Train 80% Valid 5% Test 15%

# %%
bkk_train = bkk_all.iloc[:85389*8//10]
bkk_valid = bkk_all.iloc[85389*8//10:85389*85//100]
bkk_test = bkk_all.iloc[85389*85//100:]

bkk_train.to_csv("../data/bkk_train.csv") ; pd.to_pickle(bkk_train, "../data/pd/bkk_train.pkl")
bkk_valid.to_csv("../data/bkk_valid.csv") ; pd.to_pickle(bkk_train, "../data/pd/bkk_valid.pkl")
bkk_test.to_csv("../data/bkk_test.csv") ; pd.to_pickle(bkk_train, "../data/pd/bkk_test.pkl")

# %%
bkk_train
# Out:
#                   DateTime                                   FolderPath  \
# 0      2020-06-18 06:30:00   /data/bkk_radar_images/bkk_radar_images_1/
# 1      2020-06-18 06:35:00   /data/bkk_radar_images/bkk_radar_images_1/
# 2      2020-06-18 06:45:00   /data/bkk_radar_images/bkk_radar_images_1/
# 3      2020-06-18 06:50:00   /data/bkk_radar_images/bkk_radar_images_1/
# 4      2020-06-18 06:55:00   /data/bkk_radar_images/bkk_radar_images_1/
# ...                    ...                                          ...
# 68306  2021-04-12 15:40:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68307  2021-04-12 15:45:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68308  2021-04-12 16:15:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68309  2021-04-12 16:20:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68310  2021-04-12 16:25:00  /data/bkk_radar_images/bkk_radar_images_12/
#
#              FileName
# 0      1592461954.png
# 1      1592462136.png
# 2      1592462768.png
# ...

# %%
bkk_valid
# Out:
#                   DateTime                                   FolderPath  \
# 68311  2021-04-12 16:30:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68312  2021-04-12 16:40:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68313  2021-04-12 16:45:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68314  2021-04-12 16:50:00  /data/bkk_radar_images/bkk_radar_images_12/
# 68315  2021-04-12 16:55:00  /data/bkk_radar_images/bkk_radar_images_12/
# ...                    ...                                          ...
# 72575  2021-05-01 06:15:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72576  2021-05-01 06:20:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72577  2021-05-01 06:25:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72578  2021-05-01 06:30:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72579  2021-05-01 06:35:00  /data/bkk_radar_images/bkk_radar_images_12/
#
#              FileName
# 68311  1618245142.png
# 68312  1618245740.png
# 68313  1618246046.png
# ...

# %%
bkk_test
# Out:
#                   DateTime                                   FolderPath  \
# 72580  2021-05-01 06:40:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72581  2021-05-01 06:45:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72582  2021-05-01 06:50:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72583  2021-05-01 06:55:00  /data/bkk_radar_images/bkk_radar_images_12/
# 72584  2021-05-01 07:00:00  /data/bkk_radar_images/bkk_radar_images_12/
# ...                    ...                                          ...
# 85384  2021-06-28 20:05:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85385  2021-06-28 20:35:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85386  2021-06-28 20:45:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85387  2021-06-28 21:15:00  /data/bkk_radar_images/bkk_radar_images_13/
# 85388  2021-06-28 21:20:00  /data/bkk_radar_images/bkk_radar_images_13/
#
#              FileName
# 72580  1619851342.png
# 72581  1619851642.png
# 72582  1619851938.png
# ...
