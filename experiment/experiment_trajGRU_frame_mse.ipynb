# %%
import torch
from torch.optim import lr_scheduler
import pandas as pd
import numpy as np

import os, sys
sys.path.insert(0, os.path.realpath(os.path.pardir))

from utils.config import cfg
from utils.blocks.forecaster import Forecaster
from utils.blocks.encoder import Encoder
from utils.blocks.module import EF
from utils.loss import Weighted_mse_mae
from utils.blocks.trajGRU import TrajGRU
from utils.blocks.module import Predictor
from utils.train_and_test import train_and_test
from net_params import encoder_params, forecaster_params
from utils.utils import *

# %%
batch_size = cfg.GLOBAL.BATCH_SIZE
max_iterations = 5000
test_iteration_interval = 100
test_and_save_checkpoint_iterations = 100

LR = 5e-5

encoder = Encoder(encoder_params[0], encoder_params[1]).to(cfg.GLOBAL.DEVICE)

forecaster = Forecaster(forecaster_params[0], forecaster_params[1]).to(cfg.GLOBAL.DEVICE)

encoder_forecaster = EF(encoder, forecaster).to(cfg.GLOBAL.DEVICE)

optimizer = torch.optim.Adam(encoder_forecaster.parameters(), lr=LR)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=2000, gamma=0.7)

criterion = Weighted_mse_mae(LAMBDA=0.01).to(cfg.GLOBAL.DEVICE)

folder_name = 'trajGRU_frame_BMSE'

# %%
data = torch.randn(5, 4, 1, 480, 480)
output = encoder_forecaster(data)
print(output.size())
# Out:
# torch.Size([20, 4, 1, 480, 480])

# %%
encoder_forecaster
# Out:
# EF(
#   (encoder): Encoder(
#     (rnn1): TrajGRU(
#       (i2h): Conv2d(8, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (i2f_conv1): Conv2d(8, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (h2f_conv1): Conv2d(64, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (flows_conv): Conv2d(32, 26, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (ret): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stage1): Sequential(
#       (conv1_leaky_1): Conv2d(1, 8, kernel_size=(7, 7), stride=(5, 5), padding=(1, 1))
#       (leaky_conv1_leaky_1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (rnn2): TrajGRU(
#       (i2h): Conv2d(192, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (i2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (h2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (flows_conv): Conv2d(32, 26, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (ret): Conv2d(2496, 576, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stage2): Sequential(
#       (conv2_leaky_1): Conv2d(64, 192, kernel_size=(5, 5), stride=(3, 3), padding=(1, 1))
#       (leaky_conv2_leaky_1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (rnn3): TrajGRU(
#       (i2h): Conv2d(192, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (i2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (h2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (flows_conv): Conv2d(32, 18, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (ret): Conv2d(1728, 576, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stage3): Sequential(
#       (conv3_leaky_1): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (leaky_conv3_leaky_1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (forecaster): Forecaster(
#     (rnn3): TrajGRU(
#       (i2h): Conv2d(192, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (i2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (h2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (flows_conv): Conv2d(32, 26, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (ret): Conv2d(2496, 576, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stage3): Sequential(
#       (deconv1_leaky_1): ConvTranspose2d(192, 192, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (leaky_deconv1_leaky_1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (rnn2): TrajGRU(
#       (i2h): Conv2d(192, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (i2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (h2f_conv1): Conv2d(192, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (flows_conv): Conv2d(32, 26, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (ret): Conv2d(2496, 576, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stage2): Sequential(
#       (deconv2_leaky_1): ConvTranspose2d(192, 64, kernel_size=(5, 5), stride=(3, 3), padding=(1, 1))
#       (leaky_deconv2_leaky_1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (rnn1): TrajGRU(
#       (i2h): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (i2f_conv1): Conv2d(64, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (h2f_conv1): Conv2d(64, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (flows_conv): Conv2d(32, 18, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (ret): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stage1): Sequential(
#       (deconv3_leaky_1): ConvTranspose2d(64, 8, kernel_size=(7, 7), stride=(5, 5), padding=(1, 1))
#       (leaky_deconv3_leaky_1): LeakyReLU(negative_slope=0.2, inplace=True)
#       (conv3_leaky_2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (leaky_conv3_leaky_2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (conv3_3): Conv2d(8, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
train_and_test(encoder_forecaster, optimizer, criterion, exp_lr_scheduler, batch_size, max_iterations, test_iteration_interval, test_and_save_checkpoint_iterations, folder_name)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s][ WARN:14@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598450796.png'): can't open/read file: check file path/integrity
# [ WARN:13@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598449896.png'): can't open/read file: check file path/integrity
# [ WARN:11@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598451398.png'): can't open/read file: check file path/integrity
# [ WARN:10@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598451092.png'): can't open/read file: check file path/integrity
# [ WARN:1@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609703500.png'): can't open/read file: check file path/integrity
# [ WARN:7@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609705302.png'): can't open/read file: check file path/integrity
# [ WARN:9@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609703796.png'): can't open/read file: check file path/integrity
# [ WARN:5@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598450194.png'): can't open/read file: check file path/integrity
# [ WARN:4@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598449294.png'): can't open/read file: check file path/integrity
# [ WARN:2@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598450492.png'): can't open/read file: check file path/integrity
# [ WARN:12@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598449592.png'): can't open/read file: check file path/integrity
# [ WARN:15@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609704692.png'): can't open/read file: check file path/integrity
# [ WARN:3@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609704092.png'): can't open/read file: check file path/integrity
# [ WARN:8@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609703194.png'): can't open/read file: check file path/integrity
# [ WARN:0@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609704998.png'): can't open/read file: check file path/integrity
# [ WARN:6@76.729] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609704398.png'): can't open/read file: check file path/integrity
# [ WARN:14@76.730] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609705590.png'): can't open/read file: check file path/integrity
# [ WARN:13@76.730] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598451696.png'): can't open/read file: check file path/integrity
# [ WARN:11@76.730] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609705900.png'): can't open/read file: check file path/integrity
# [ WARN:10@76.730] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598451992.png'): can't open/read file: check file path/integrity
# [ WARN:7@76.731] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598452296.png'): can't open/read file: check file path/integrity
# [ WARN:1@76.731] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609706196.png'): can't open/read file: check file path/integrity
# [ WARN:9@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609706492.png'): can't open/read file: check file path/integrity
# [ WARN:5@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598452592.png'): can't open/read file: check file path/integrity
# [ WARN:4@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609706798.png'): can't open/read file: check file path/integrity
# [ WARN:2@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598452898.png'): can't open/read file: check file path/integrity
# [ WARN:12@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609707094.png'): can't open/read file: check file path/integrity
# [ WARN:15@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598453194.png'): can't open/read file: check file path/integrity
# [ WARN:3@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609707394.png'): can't open/read file: check file path/integrity
# [ WARN:15@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598453500.png'): can't open/read file: check file path/integrity
# [ WARN:8@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609707704.png'): can't open/read file: check file path/integrity
# [ WARN:6@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598453798.png'): can't open/read file: check file path/integrity
# [ WARN:14@76.732] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609707998.png'): can't open/read file: check file path/integrity
# [ WARN:13@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598454092.png'): can't open/read file: check file path/integrity
# [ WARN:11@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609708298.png'): can't open/read file: check file path/integrity
# [ WARN:10@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598454398.png'): can't open/read file: check file path/integrity
# [ WARN:7@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609708592.png'): can't open/read file: check file path/integrity
# [ WARN:1@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598454692.png'): can't open/read file: check file path/integrity
# [ WARN:7@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609708902.png'): can't open/read file: check file path/integrity
# [ WARN:9@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598454998.png'): can't open/read file: check file path/integrity
# [ WARN:5@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609709196.png'): can't open/read file: check file path/integrity
# [ WARN:4@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598455298.png'): can't open/read file: check file path/integrity
# [ WARN:2@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609709492.png'): can't open/read file: check file path/integrity
# [ WARN:12@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598455594.png'): can't open/read file: check file path/integrity
# [ WARN:3@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598455898.png'): can't open/read file: check file path/integrity
# [ WARN:0@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609709796.png'): can't open/read file: check file path/integrity
# [ WARN:15@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609710092.png'): can't open/read file: check file path/integrity
# [ WARN:8@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598456194.png'): can't open/read file: check file path/integrity
# [ WARN:6@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_101609710396.png'): can't open/read file: check file path/integrity
# [ WARN:14@76.733] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_41598456502.png'): can't open/read file: check file path/integrity
#   0%|          | 1/5000 [00:29<41:22:45, 29.80s/it][ WARN:11@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596959788.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606605098.png'): can't open/read file: check file path/integrity
# [ WARN:13@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606604802.png'): can't open/read file: check file path/integrity
# [ WARN:5@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606605404.png'): can't open/read file: check file path/integrity
# [ WARN:9@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596960092.png'): can't open/read file: check file path/integrity
# [ WARN:5@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596960390.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606605698.png'): can't open/read file: check file path/integrity
# [ WARN:9@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596960694.png'): can't open/read file: check file path/integrity
# [ WARN:13@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606606004.png'): can't open/read file: check file path/integrity
# [ WARN:13@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596960990.png'): can't open/read file: check file path/integrity
# [ WARN:13@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606606300.png'): can't open/read file: check file path/integrity
# [ WARN:4@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596961296.png'): can't open/read file: check file path/integrity
# [ WARN:13@106.509] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606606604.png'): can't open/read file: check file path/integrity
# [ WARN:5@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596961592.png'): can't open/read file: check file path/integrity
# [ WARN:11@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606606900.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596961900.png'): can't open/read file: check file path/integrity
# [ WARN:11@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606607204.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596962198.png'): can't open/read file: check file path/integrity
# [ WARN:13@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606607500.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596962496.png'): can't open/read file: check file path/integrity
# [ WARN:9@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606607804.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596962792.png'): can't open/read file: check file path/integrity
# [ WARN:9@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606608100.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596963098.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606608396.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596963394.png'): can't open/read file: check file path/integrity
# [ WARN:4@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606608702.png'): can't open/read file: check file path/integrity
# [ WARN:4@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596963690.png'): can't open/read file: check file path/integrity
# [ WARN:4@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606608998.png'): can't open/read file: check file path/integrity
# [ WARN:4@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596963996.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606609298.png'): can't open/read file: check file path/integrity
# [ WARN:9@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596964292.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606609604.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596964600.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606609900.png'): can't open/read file: check file path/integrity
# [ WARN:10@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596964896.png'): can't open/read file: check file path/integrity
# [ WARN:5@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606610196.png'): can't open/read file: check file path/integrity
# [ WARN:5@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596965192.png'): can't open/read file: check file path/integrity
# [ WARN:5@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606610500.png'): can't open/read file: check file path/integrity
# [ WARN:12@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596965498.png'): can't open/read file: check file path/integrity
# [ WARN:3@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606610796.png'): can't open/read file: check file path/integrity
# [ WARN:11@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596965794.png'): can't open/read file: check file path/integrity
# [ WARN:11@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596966090.png'): can't open/read file: check file path/integrity
# [ WARN:11@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606611400.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596966396.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606611696.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596966692.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_81606612008.png'): can't open/read file: check file path/integrity
# [ WARN:2@106.510] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('bkk_radar_images_dBZ_31596966998.png'): can't open/read file: check file path/integrity

# %%
# from utils.tools.evaluation import *
# from utils.tools.dataloader import BKKIterator
# import copy
# import time
# import pickle

# IN_LEN = cfg.BENCHMARK.IN_LEN
# OUT_LEN = cfg.BENCHMARK.OUT_LEN
# name = 'conv2d'

# %%
# with torch.no_grad():
#     is_deeplearning_model = (torch.nn.Module in model.__class__.__bases__)
#     if is_deeplearning_model:
#         model.eval()
#     evaluator = Evaluation(seq_len=OUT_LEN, use_central=False)
#     bkk_iter = BKKIterator(pd_path=cfg.ONM_PD.RAINY_TEST,
#                                     sample_mode="sequent",
#                                     seq_len=IN_LEN + OUT_LEN,
#                                     stride=cfg.BENCHMARK.STRIDE)
#     model_run_avarage_time = dict()
#     model_run_avarage_time[name] = 0.0
#     valid_time = 0
#     while not bkk_iter.use_up:
#         valid_batch, valid_mask, sample_datetimes, _ = bkk_iter.sample(batch_size=1)
#         if valid_batch.shape[1] == 0:
#             break
#         if not cfg.EVALUATION.VALID_DATA_USE_UP and valid_time > cfg.EVALUATION.VALID_TIME:
#             break

#         valid_batch = valid_batch.astype(np.float32) / 255.0
#         valid_data = valid_batch[:IN_LEN, ...]
#         valid_label = valid_batch[IN_LEN:IN_LEN + OUT_LEN, ...]
#         mask = valid_mask[IN_LEN:IN_LEN + OUT_LEN, ...].astype(int)

#         if is_deeplearning_model:
#             valid_data = torch.from_numpy(valid_data).to(cfg.GLOBAL.DEVICE)

#         start = time.time()
#         output = model(valid_data)
#         model_run_avarage_time[name] += time.time() - start

#         if is_deeplearning_model:
#             output = output.cpu().numpy()

#         output = np.clip(output, 0.0, 1.0)

#         evaluator.update(valid_label, output, mask)

#         valid_time += 1
#     model_run_avarage_time[name] /= valid_time
#     evaluator.save_pkl(os.path.join(cfg.BENCHMARK.STAT_PATH, name + '.pkl'))

# %%
# with open(os.path.join(cfg.BENCHMARK.STAT_PATH, 'model_run_avarage_time.pkl'), 'wb') as f:
#     pickle.dump(model_run_avarage_time, f)

# %%
# for p in os.listdir(os.path.abspath(cfg.BENCHMARK.STAT_PATH))[:1]:
#     e = pickle.load(open(os.path.join(cfg.BENCHMARK.STAT_PATH, p), 'rb'))
#     _, _, csi, hss, _, mse, mae, balanced_mse, balanced_mae, _ = e.calculate_stat()
#     print(p.split('.')[0])
#     for i, thresh in enumerate(cfg.EVALUATION.THRESHOLDS):
#         print('thresh %.1f csi: average %.4f, last frame %.4f; hss: average %.4f, last frame %.4f;'
#               % (thresh, csi[:, i].mean(), csi[-1, i], hss[:, i].mean(), hss[-1, i]))

#     print(('mse: average %.2f, last frame %.2f\n' +
#         'mae: average %.2f, last frame %.2f\n'+
#         'bmse: average %.2f, last frame %.2f\n' +
#         'bmae: average %.2f, last frame %.2f\n') % (mse.mean(), mse[-1], mae.mean(), mae[-1],
#               balanced_mse.mean(), balanced_mse[-1], balanced_mae.mean(), balanced_mae[-1]))
